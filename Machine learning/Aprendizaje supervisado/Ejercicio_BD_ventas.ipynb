# %% [markdown]
# # Ejercicio concatenación de bases de datos

# %%
import pandas as pd

# %%
# ejemplo con varias bases

v_2018 = './datasets/Ventas_2018.xlsx'
v_2019 = './datasets/Ventas_2019.xlsx'
v_2020 = './datasets/Ventas_2020.xlsx'
v_2021 = './datasets/Ventas_2021.xlsx'

df_1 = pd.read_excel(v_2018) 
df_2 = pd.read_excel(v_2019)
df_3 = pd.read_excel(v_2020)
df_4 = pd.read_excel(v_2021)

df_ventas_previa = pd.concat([df_2,df_3,df_4], axis=0, ignore_index=True)
df_ventas_final = pd.concat([df_1, df_ventas_previa], axis=0, ignore_index=True)

# %%
#Cargar los datos
display(df_ventas_final)
# Out:
#        Fecha_venta        Nit                   Nombre_Cliente  \
# 0       2018-01-04  883582190     ABASTECEMOS DE OCCIDENTE S.A
# 1       2018-01-04  877794213                    AGROSANAR SAS
# 2       2018-01-04  806153817              ALKOSTO HIPERAHORRO
# 3       2018-01-04  811548593              ALMACENES EXITO S.A
# 4       2018-01-04  822018800               ALMACENES OLIMPICA
# ...            ...        ...                              ...
# 212250  2021-12-28  820013672              TIENDA LOS RINCONES
# 212251  2021-12-28  841327549         TIENDA MARIA AUXILIADORA
# 212252  2021-12-28  887188274                     TIENDA OLAYA
# 212253  2021-12-28  822055565  TRUJILLO JIMENEZ CAMILO ERNESTO
# 212254  2021-12-28  880572520                    YADID GRANADA
#
#            Tipo Cliente Departamento                Vendedor Sucursal  \
# 0       CADENA REGIONAL    ANTIOQUIA  MARIA YULIETH AMARILES    NORTE
# 1       CADENA REGIONAL    ANTIOQUIA       DIEGO MORA POSADA      SUR
# 2       CADENA NACIONAL    ANTIOQUIA    PAULA ANDREA ARTEAGA   CENTRO
# 3       CADENA NACIONAL    ANTIOQUIA   SILVIA CAROLINA LOPEZ    NORTE
# 4       CADENA NACIONAL    ANTIOQUIA     SHIRLEY MARIN MARIN      SUR
# ...                 ...          ...                     ...      ...
# 212250      MINIMERCADO    ANTIOQUIA     SHIRLEY MARIN MARIN    NORTE
# 212251      MINIMERCADO    ANTIOQUIA     SHIRLEY MARIN MARIN    NORTE
# 212252      MINIMERCADO    ANTIOQUIA     SHIRLEY MARIN MARIN    NORTE
# 212253    INSTITUCIONAL    ANTIOQUIA     SHIRLEY MARIN MARIN    NORTE
# 212254      MINIMERCADO    ANTIOQUIA     SHIRLEY MARIN MARIN    NORTE
#
#        Categoría              Producto    Linea  Cantidad         Venta  \
# 0         LACTEA          LECHE ENTERA  LACTEOS         3  27000.000000
# 1         LACTEA     LECHE ENTERA MINI  LACTEOS         3  25500.000000
# 2         LACTEA      LECHE DESCREMEDA  LACTEOS         2  16004.000000
# 3         LACTEA    LECHE DESLACTOSADA  LACTEOS         2  18574.000000
# 4         LACTEA  LECHE SEMIDESCREMADA  LACTEOS         3  26256.000000
# ...          ...                   ...      ...       ...           ...
# 212250    HELADO          HELADO FRESA  HELADOS         2   6499.440000
# 212251    HELADO           HELADO MORA  HELADOS         2   5065.503256
# 212252    HELADO    HELADO TRES LECHES  HELADOS         1   2659.773227
# 212253    LACTEA       QUESO CREMA FIT      FIT         6  53085.180000
# 212254    LACTEA             QUESO FIT      FIT         1   4339.290000
#
#               Costos
# 0       11420.480226
# 1       12195.596484
# 2        8541.105250
# 3       14032.797920
# 4       20842.800663
# ...              ...
# 212250   2173.847146
# 212251   2302.147216
# 212252   1068.661480
# 212253  30451.011564
# 212254   2182.284723
#
# [212255 rows x 13 columns]
